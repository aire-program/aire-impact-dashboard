# %% [markdown]
# # KPI Exploration
#
# This notebook explores the core Key Performance Indicators (KPIs) used in the dashboard.

# %%
import pandas as pd
import plotly.express as px
import sys
import os

# Add parent dir to path to import app modules
sys.path.append(os.path.abspath(os.path.join('..')))

from app.data_loader import load_all_data
from app.kpi_calculations import calculate_confidence_deltas

# %%
data = load_all_data()
print("Data loaded successfully")

# %%
# Calculate Deltas
deltas = calculate_confidence_deltas(data['assessments_pre'], data['assessments_post'])
print(deltas)
