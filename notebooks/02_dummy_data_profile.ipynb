# %% [markdown]
# # Dummy Data Profile
#
# Profiling the synthetic datasets to ensure realistic distributions.

# %%
import pandas as pd
import sys
import os

sys.path.append(os.path.abspath(os.path.join('..')))
from app.data_loader import load_all_data

# %%
data = load_all_data()
for name, df in data.items():
    print(f"Dataset: {name}")
    print(df.info())
    print("\n")
