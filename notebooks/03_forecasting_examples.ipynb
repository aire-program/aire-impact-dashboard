# %% [markdown]
# # Forecasting Examples
#
# Demonstrating simple forecasting techniques for workshop demand.

# %%
import pandas as pd
import sys
import os

sys.path.append(os.path.abspath(os.path.join('..')))
from app.data_loader import load_all_data
from app.kpi_calculations import forecast_registrations

# %%
data = load_all_data()
workshops = data['workshops']

forecast = forecast_registrations(workshops, periods=6)
print("Forecasted Registrations (Next 6 Months):")
for date, val in forecast:
    print(f"{date.date()}: {int(val)}")
